# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:/Users/hp/Desktop/data science industrial program/supermarket_sales.csv')

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data.describe(include='all')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
data.Rating.describe()
# Out:
# count    1000.00000
# mean        6.97270
# std         1.71858
# min         4.00000
# 25%         5.50000
# 50%         7.00000
# 75%         8.50000
# max        10.00000
# Name: Rating, dtype: float64

# %%
rating=data['Rating']

# %%
rating.median()
# Out:
# 7.0

# %%
rating.head()
# Out:
# 0    9.1
# 1    9.6
# 2    7.4
# 3    8.4
# 4    5.3
# Name: Rating, dtype: float64

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

# %%
data.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.distplot(data['Unit price'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\3751734877.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Unit price'])
# <Axes: xlabel='Unit price', ylabel='Density'>

# %%
rating.skew()
# Out:
# 0.00900964876573073

# %%
sns.distplot(data['Tax 5%'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\3592845394.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Tax 5%'])
# <Axes: xlabel='Tax 5%', ylabel='Density'>

# %%
sns.distplot(data['Total'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\1558581430.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total'])
# <Axes: xlabel='Total', ylabel='Density'>

# %%
sns.distplot(data['gross income'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\447928604.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['gross income'])
# <Axes: xlabel='gross income', ylabel='Density'>

# %%
sns.distplot(data['cogs'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\4282832329.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['cogs'])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data['Rating'],order=data['Rating'].value_counts().index)
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %%
data.cov()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\4020818503.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.cov()
#                           Unit price    Quantity       Tax 5%         Total  \
# Unit price                701.965331    0.834778   196.668340   4130.035142
# Quantity                    0.834778    8.546446    24.149570    507.140978
# Tax 5%                    196.668340   24.149570   137.096594   2879.028477
# Total                    4130.035142  507.140978  2879.028477  60459.598018
# cogs                     3933.366802  482.991408  2741.931883  57580.569541
# gross margin percentage     0.000000    0.000000     0.000000      0.000000
# gross income              196.668340   24.149570   137.096594   2879.028477
# ...

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8004\2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # What does the customer rating look like and is it skewed?(Use normal distribution plot)

# %%
import pandas as pd
import seaborn as sns


# Plot  a normal distribution plot for customer rating
sns.kdeplot(data['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# - Rating is not skewed and data is normally distributed

# %% [markdown]
# # Is there any difference in aggregate sales across branches?(Use bar graph)

# %%
branch_sales=data.groupby('Branch')['Total'].sum()

plt.bar(branch_sales.index,branch_sales.values,width=0.5,color='blue')
plt.title('Total Sales by Branches')
plt.ylabel("Sales_Total")
plt.xlabel("Branches")
# Out:
# Text(0.5, 0, 'Branches')

# %% [markdown]
# # the most popular payment method used by customers?(Use bar graph)

# %%
payment_method_count=data['Payment'].value_counts()
payment_method_count=payment_method_count.sort_values(ascending=False)
plt.bar(payment_method_count.index,payment_method_count.values,width=0.5,color='blue',label=True)
plt.title('Payment_method_count')
plt.xlabel("payment method")
plt.ylabel("count of customers")
# Out:
# Text(0, 0.5, 'count of customers')

# %% [markdown]
# # Does gross income affect the ratings that the customers provide?(Use scatterplot)

# %%
sns.scatterplot(y='gross income',x='Rating',data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='gross income'>

# %% [markdown]
# # Which branch is the most profitable?(Use Boxplot)

# %%
sns.boxplot(x='Branch',y='gross income',data=data)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# # Is there any relationship between Gender and Gross income?

# %%
sns.boxplot(x='Gender',y='gross income',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.barplot(x='Gender',y='gross income',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# # Is there any time trend in gross income? (Use line graph)

# %%
df=data

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(20,10))
timetrend=df.groupby('Date')['gross income'].sum()

plt.plot( timetrend)
plt.title('Time Trend of Gross Income')
plt.xlabel('Date')
plt.ylabel('Gross Income')
# Out:
# Text(0, 0.5, 'Gross Income')

# %%
timetrend
# Out:
# Date
# 2019-01-01    225.9610
# 2019-01-02     92.6430
# 2019-01-03     98.9585
# 2019-01-04     77.3185
# 2019-01-05    168.4135
#                 ...
# 2019-03-26     93.4530
# 2019-03-27    138.2295
# 2019-03-28    106.1620
# 2019-03-29    191.5830
# 2019-03-30    213.6695
# Name: gross income, Length: 89, dtype: float64

# %% [markdown]
# # Which product line generates most income?(Use Bar plot)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Product line',y='Total', data=data)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # What is the spending pattern of females and males and in which category do they spend a lot?(Use countplot in Seaborn Python package)

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Product line',hue='Gender',data=data)
plt.title("Spending Pattern of Males and Females in Each Product Line")
plt.xlabel("Product Line")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # How many products are bought by customers?(Use distribution plot)

# %%
sns.displot(data=df, x="Quantity", kind="kde", fill=True, aspect=2)
plt.title("Distribution of Number of Products Bought by Customers")
plt.xlabel("Quantity")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# # Which day of the week has maximum sales?(Use countplot)

# %%
data=pd.read_csv('C:/Users/hp/Desktop/data science industrial program/supermarket_sales.csv')

# %%
import datetime  
from datetime import date 
def dtd(date):
    month,day, year = date.split('/')     
    day_name = datetime.date(int(year), int(month), int(day)) 
    return day_name.strftime("%A")

# %%
day=[dtd(i) for i in data['Date']]

# %%
data['Day']=day

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data['Day'])

# sns.set(rc={'figure.figsize':(15,10)})
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %% [markdown]
# # Which hour of the day is the busiest?(Use line plot)

# %%
hour=[i[:2] for i in df['Time']]
data['Hour']=hour

# %%
data.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6
#
#         Day Hour
# 0  Saturday   13
# 1    Friday   10

# %%
sns.lineplot(y=data['Invoice ID'].groupby(data['Hour']).count(),x=sorted(data['Hour'].unique()))
# Out:
# <Axes: ylabel='Invoice ID'>

# %%
y=data['Invoice ID'].groupby(data['Hour']).count()
y
# Out:
# Hour
# 10    101
# 11     90
# 12     89
# 13    103
# 14     83
# 15    102
# 16     77
# 17     74
# 18     93
# 19    113
# 20     75
# Name: Invoice ID, dtype: int64

# %% [markdown]
# # Which product line should the supermarket focus on?(Use bar plot)

# %%
pl=data['Total'].groupby(data['Product line']).sum().to_frame()
pl
# Out:
#                              Total
# Product line
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Food and beverages      56144.8440
# Health and beauty       49193.7390
# Home and lifestyle      53861.9130
# Sports and travel       55122.8265

# %%
plt.figure(figsize=(20,10))

sns.barplot(y=data['Total'].groupby(data['Product line']).sum(),x=sorted(data['Product line'].unique()))
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# # Which city should be chosen for expansion and which products should it focus on?(Use bar plot)

# %%
ct=data['Total'].groupby(data['City']).sum().to_frame()
ct
# Out:
#                  Total
# City
# Mandalay   106197.6720
# Naypyitaw  110568.7065
# Yangon     106200.3705

# %%
sns.barplot(y=data['Total'].groupby(data['City']).sum(),x=sorted(data['City'].unique()))
# Out:
# <Axes: ylabel='Total'>

# %%
t=data.where(data['City']=='Naypyitaw')

# %%
pl=t['Total'].groupby(t['Product line']).sum().to_frame()
pl
# Out:
#                              Total
# Product line
# Electronic accessories  18968.9745
# Fashion accessories     21560.0700
# Food and beverages      23766.8550
# Health and beauty       16615.3260
# Home and lifestyle      13895.5530
# Sports and travel       15761.9280

# %%
plt.figure(figsize=(20,10))
sns.barplot(y=t['Total'].groupby(t['Product line']).sum(),x=sorted(df['Product line'].unique()))
# Out:
# <Axes: ylabel='Total'>
